# %% [markdown]
# # 프로젝트: 이제까지 만들었던 모델을 튜닝하고 배포하기!

# %% [markdown]
# ## Rubric 01 : 그림에 맞게 딥러닝 모델 설계

# %% [markdown]
# **주어진 모델 그림**
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Sequential 모델 생성
model = models.Sequential([
    # 첫 번째 Convolutional 레이어
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    # 첫 번째 Average Pooling 레이어
    layers.AveragePooling2D(),
    layers.BatchNormalization(),
    # 두 번째 Convolutional 레이어
    layers.Conv2D(64, (3, 3), activation='relu'),
    # 두 번째 Average Pooling 레이어
    layers.AveragePooling2D(),
    layers.BatchNormalization(),
    # Flatten 레이어
    layers.Flatten(),
    # 첫 번째 Fully Connected(Dense) 레이어
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),  # 첫 번째 Dropout 추가
    # 출력 레이어
    layers.Dense(10)
])

# 모델 summary 출력
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 15, 15, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 15, 15, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 6, 6, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# ...

# %% [markdown]
# ## Rubric 02 : 틀린 Label 22개 시각화 > Label 수정

# %% [markdown]
# ## Rubirc 03 : KerasTuner를 정상작동 > 하이퍼파라미터 튜닝 > 최적화된 하이퍼파라미터로 모델 학습
